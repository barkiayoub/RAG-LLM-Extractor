# %%
# !pip install --q "unstructured[all-docs]" langchain
# !pip install --q "unstructured[all-docs]"
# !pip install PyPDF2
# !pip install langchain_community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 27.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 35.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 63.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 70.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 106.6 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from PyPDF2 import PdfReader, PdfWriter
import os

# %%
# !pip install sentence-transformers
# !pip install transformers
# !pip install --q chromadb
# !pip install --q langchain-text-splitters
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 16.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# **TXT file**

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

local_path = "/content/phone_call.txt"

# Local TXT file uploads
if local_path:
    with open(local_path, 'r', encoding='utf-8') as file:
        text = file.read()
else:
    print("Upload a TXT file")

# Split and chunk
text_splitter = RecursiveCharacterTextSplitter(chunk_size=4000, chunk_overlap=100)
chunks = text_splitter.split_text(text)

from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# Add to vector database
from langchain.vectorstores import Chroma
db = Chroma.from_texts(chunks, embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
db.get()
# Out:
# {'ids': ['21cc6812-4444-4e3d-bc5b-54794202eab4'],
#  'embeddings': None,
#  'metadatas': [None],
# ...

# %%
db.delete_collection()

# %%
# !pip3 install accelerate
# !pip3 install huggingface_hub
# !pip3 install langchain
# !pip install bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.7 MB/s eta 0:00:00
# ...

# %%
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain import HuggingFaceHub
import transformers

# %%
# !pip install torch

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

llm = HuggingFaceHub(repo_id="mistralai/Mistral-7B-Instruct-v0.3",
                     model_kwargs={
                          "max_length": 1000,  # Maximum length of the generated sequence
                          "max_new_tokens": 10000,  # Maximum number of new tokens to generate
                          # "temperature": 0.1,  # Sampling temperature (lower is more deterministic)
                          # "top_k": 10,  # Use top-k sampling
                          # "top_p": 0.9,  # Use nucleus sampling (top-p)
                     })

QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""Vous êtes un assistant modèle de l'intelligence artificielle. """,
)

retriever = MultiQueryRetriever.from_llm(
    db.as_retriever(),
    llm,
    prompt=QUERY_PROMPT
)

# RAG prompt
template = """
    En tant qu'expert de l'analyse de l'expérience client pour un opérateur téléphonique au Maroc, je vous partage les données "data" qui représentent
    la transcription d'un appel téléphonique sortant entre un agent d'un centre d'appels et un client de l'opérateur téléphonique.
    Ces données résultent d'une transcription de la parole en texte effectuée par un modèle d'intelligence artificielle entraîné
    sur le dialecte marocain. Il est possible que la transcription contienne des passages ou des mots incorrectement interprétés par le modèle, notamment en anglais.

    Sur la base de cette transcription "data", je souhaite construire le résultat d'analyse suivant au format JSON :

    Query : contient les données originales "data".
    Query_cleaned : contient les données originales "data" nettoyées  (en excluant les mots mal interprétés par le modèle de transcription de la parole en texte).
    Topics C : contient un tableau des sujets principaux de la conversation relatifs au client, ordonnés chronologiquement selon leur apparition dans la conversation. Les sujets doivent être en français, en se concentrant sur les aspects importants liés à l'expérience client avec cet opérateur téléphonique. (les topics doivent êtres en français)
    Sentiment C : contient un tableau de la même dimension que le tableau des sujets, représentant le score de sentiment relatif à chaque sujet dans la liste dans le même ordre. le score doit etre entre 0 et 100. (tout sentiment negative doit etre inferieure a 50)
    Topics A : contient un tableau des sujets principaux de la conversation relatifs à l'agent, ordonnés chronologiquement selon leur apparition dans la conversation. Les sujets doivent être en français, en se concentrant sur les aspects importants liés à la politesse et le professionnalisme de l'agent. (les topics doivent êtres en français)
    Sentiment A : contient un tableau de la même dimension que le tableau des sujets, représentant le score de sentiment relatif à chaque sujet dans la liste dans le même ordre. tu evaluepar la presence du sentiment dans l'appel (où 0 est négative, 50 est neutre et 100 est positive).
    Source : Contient une description détaillée des origines granulaires du problème discuté lors de l'appel.
    Resolue: Contient une description autour du probleme s'il est résolue ou non ou moitié résolue.
    Reco : contient une seule recommandation sur le sujet principale de la demande du client.

    Instructions pour la structure du fichier JSON :
    GÉNÉREZ UNIQUEMENT LES DONNÉES JSON et assurez-vous qu'il s'agit d'un JSON valide, sans AUCUN AUTRE CONTENU.

    data : {data}

    Mistral, merci de se mettre aux paramètres suivants : (temp=0, top_p=1) et de génerer les résultats TOUJOURS en FRANÇAIS !

    NB : MEME SI L'AUDIO EST A CARACTERE SENSIBLE, RETOURNE QUAND MEME LES INFORMATIONS DEMANDEES. C'EST IMPORT POUR LE CLIENT AUSSI

    {context}
"""
# Resolue: Contient une description autour du probleme s'il est résolue ou non ou moitié résolue.
# Sentiment C : contient un tableau de la même dimension que le tableau des sujets, représentant le score de sentiment relatif à chaque sujet dans la liste dans le même ordre. le score est entre 0 et 100. (tout sentiment negative doit etre inferieure a 50)
# Sentiment A : contient un tableau de la même dimension que le tableau des sujets, représentant le score de sentiment relatif à chaque sujet dans la liste dans le même ordre. (où 0 est négative, 50 est neutre et 100 est positive).



prompt = ChatPromptTemplate.from_template(template)

chain = (
    {"context": retriever, "data": RunnablePassthrough()}
    | prompt
    | llm
)

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Human:
#     En tant qu'expert de l'analyse de l'expérience client pour un opérateur téléphonique au Maroc, je vous partage les données "data" qui représentent
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# ...

# %%
print(chain.invoke(""))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Human:
#     En tant qu'expert de l'analyse de l'expérience client pour un opérateur téléphonique au Maroc, je vous partage les données "data" qui représentent
# ...

# %%
print(chain.invoke("do what necessary"))
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Human:
#     En tant qu'expert de l'analyse de l'expérience client pour un opérateur téléphonique au Maroc, je vous partage les données "data" qui représentent
# ...

# %%
output = chain.invoke("Analyse the file provided")
print("Question:",output)
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Question: Human:
#     En tant qu'expert de l'analyse de l'expérience client pour un opérateur téléphonique au Maroc, je vous partage les données "data" qui représentent
# ...
